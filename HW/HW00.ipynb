# %% [markdown]
# <a href="https://colab.research.google.com/github/baektaehee1026-ui/newspace/blob/main/HW/HW00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
I = plt.imread("IMG_0917.jpg")
print(I.shape)
print(I.dtype)
plt.imshow(I)
plt.show()
# Out:
# (648, 1179, 3)
# uint8
